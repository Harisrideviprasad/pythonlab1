# %% [markdown]
# <a href="https://colab.research.google.com/github/Harisrideviprasad/pythonlab1/blob/main/week_1/pythonprog1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hari")
# Out:
# hari

# %%
a=input()
# Out:
# 22

# %%
a
# Out:
# '22'

# %%
a=int(input())
# Out:
# 22

# %%
a
# Out:
# 22

# %%
a=int(input())
b=float(input())
a+b
# Out:
# 22
# 2.5
# 24.5

# %%
a,b
# Out:
# (22, 2.5)

# %%
a=22
b=25
a*b
# Out:
# 550

# %%
x=22
print(type(x))
# Out:
# <class 'int'>

# %%
a=12
b=6
a//b
# Out:
# 2

# %%
a=22
b=10
a/b
# Out:
# 2.2

# %%
a=str(input())
# Out:
# hari

# %%
a=int(input())
b=int(input())
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a**b)
# Out:
# 22
# 25
# 47
# -3
# 550
# 0
# 3635524038174209847159494312722432
