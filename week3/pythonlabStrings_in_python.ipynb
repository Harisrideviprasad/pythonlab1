# %% [markdown]
# <a href="https://colab.research.google.com/github/Harisrideviprasad/pythonlab1/blob/main/week3/pythonlabStrings_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#string methods
#1.split
#2.join
#3.strip
#4.upper and lower
#5.replace
#6.find
#7.count

# %%
#examples for string methods
a=str(input())
b=a.split()
print(b)
# Out:
# eren yeager
# ['eren', 'yeager']

# %%
c=" ".join(b)
print(c)
# Out:
# eren yeager

# %%
y="James Lee"
print(y.strip())
# Out:
# James Lee

# %%
y="james lee"
print(y.upper())
# Out:
# JAMES LEE

# %%
x="RONALDO"
print(x.lower())
# Out:
# ronaldo

# %%
z=a.replace("eren","Hari")
print(z)
# Out:
# Hari yeager

# %%
print(z.find("H"))
# Out:
# 0

# %%
print(z.count("H"))
# Out:
# 1

# %%
#program that count the no of vowels and consonants in a string
a=str(input())
b=a.lower()
vowels="aeiou"
count_v=0
count_c=0
for ch in b:
  if ch.isalpha():
    if ch in vowels:
     count_v+=1
    else:
      count_c+=1
print("no of vowels are",count_v)
print("no of consonants are",count_c)
# Out:
# erenyeager
# no of vowels are 5
# no of consonants are 5

# %%
#program that checks the sub string is in the original string if yes print the index of substring
a=str(input())
b=str(input())
if b in a:
  print(a.find(b))
else:
  print("not present")
# Out:
# hariyeager
# yeager
# 4
